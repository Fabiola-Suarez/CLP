# %% [markdown]
# # TP 2 - Analisis de datos sobre los lenguajes de programacion mas usados
#
# En este notebook se crea y analiza un dataset con los lenguajes de programacion mas populares segun el indice TIOBE de junio de 2026. La idea es seguir los pasos del ejemplo del resumen: cargar datos, revisar valores nulos, buscar duplicados, limpiar informacion y generar visualizaciones.

# %% [markdown]
# ## 1. Importacion de librerias

# %%
# %pip install pandas matplotlib

import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 30)
# Out:
# Requirement already satisfied: pandas in c:\users\fabiola\appdata\local\programs\python\python312\lib\site-packages (3.0.3)
# Requirement already satisfied: matplotlib in c:\users\fabiola\appdata\local\programs\python\python312\lib\site-packages (3.10.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\fabiola\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\fabiola\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\fabiola\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\fabiola\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\fabiola\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\fabiola\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\fabiola\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\fabiola\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\fabiola\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\fabiola\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\fabiola\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 2. Creacion del dataset
#
# Ranking actual, ranking del año anterior, en lenguaje, porcentaje de popularidad y la variacion interanual.

# %%
datos_lenguajes = [
    {"ranking_2026": 1, "ranking_2025": 1, "lenguaje": "Python", "porcentaje": 18.96, "variacion": -6.91, "paradigma_principal": "multiparadigma"},
    {"ranking_2026": 2, "ranking_2025": 3, "lenguaje": "C", "porcentaje": 10.77, "variacion": 1.30, "paradigma_principal": "imperativo"},
    {"ranking_2026": 3, "ranking_2025": 2, "lenguaje": "C++", "porcentaje": 8.03, "variacion": -2.65, "paradigma_principal": "multiparadigma"},
    {"ranking_2026": 4, "ranking_2025": 4, "lenguaje": "Java", "porcentaje": 7.90, "variacion": -0.94, "paradigma_principal": "orientado a objetos"},
    {"ranking_2026": 5, "ranking_2025": 5, "lenguaje": "C#", "porcentaje": 4.85, "variacion": 0.17, "paradigma_principal": "orientado a objetos"},
    {"ranking_2026": 6, "ranking_2025": 6, "lenguaje": "JavaScript", "porcentaje": 3.04, "variacion": -0.17, "paradigma_principal": "multiparadigma"},
    {"ranking_2026": 7, "ranking_2025": 8, "lenguaje": "Visual Basic", "porcentaje": 2.80, "variacion": 0.59, "paradigma_principal": "orientado a eventos"},
    {"ranking_2026": 8, "ranking_2025": 12, "lenguaje": "SQL", "porcentaje": 1.77, "variacion": 0.23, "paradigma_principal": "declarativo"},
    {"ranking_2026": 9, "ranking_2025": 14, "lenguaje": "R", "porcentaje": 1.69, "variacion": 0.30, "paradigma_principal": "funcional"},
    {"ranking_2026": 10, "ranking_2025": 9, "lenguaje": "Delphi/Object Pascal", "porcentaje": 1.54, "variacion": -0.60, "paradigma_principal": "orientado a objetos"},
    {"ranking_2026": 11, "ranking_2025": 16, "lenguaje": "Scratch", "porcentaje": 1.46, "variacion": 0.27, "paradigma_principal": "visual"},
    {"ranking_2026": 12, "ranking_2025": 18, "lenguaje": "Rust", "porcentaje": 1.26, "variacion": 0.30, "paradigma_principal": "multiparadigma"},
    {"ranking_2026": 13, "ranking_2025": 7, "lenguaje": "Go", "porcentaje": 1.20, "variacion": -1.08, "paradigma_principal": "imperativo"},
    {"ranking_2026": 14, "ranking_2025": 15, "lenguaje": "PHP", "porcentaje": 1.17, "variacion": -0.08, "paradigma_principal": "multiparadigma"},
    {"ranking_2026": 15, "ranking_2025": 25, "lenguaje": "Swift", "porcentaje": 1.00, "variacion": 0.27, "paradigma_principal": "multiparadigma"},
    {"ranking_2026": 16, "ranking_2025": 11, "lenguaje": "Ada", "porcentaje": 0.97, "variacion": -0.74, "paradigma_principal": "imperativo"},
    {"ranking_2026": 17, "ranking_2025": 10, "lenguaje": "Fortran", "porcentaje": 0.95, "variacion": -0.91, "paradigma_principal": "imperativo"},
    {"ranking_2026": 18, "ranking_2025": 13, "lenguaje": "Perl", "porcentaje": 0.92, "variacion": -0.55, "paradigma_principal": "multiparadigma"},
    {"ranking_2026": 19, "ranking_2025": 19, "lenguaje": "Assembly language", "porcentaje": 0.87, "variacion": -0.04, "paradigma_principal": "bajo nivel"},
    {"ranking_2026": 20, "ranking_2025": 17, "lenguaje": "MATLAB", "porcentaje": 0.85, "variacion": -0.28, "paradigma_principal": "multiparadigma"},
]

df = pd.DataFrame(datos_lenguajes)
df
# Out:
#     ranking_2026  ranking_2025              lenguaje  porcentaje  variacion  \
# 0              1             1                Python       18.96      -6.91
# 1              2             3                     C       10.77       1.30
# 2              3             2                   C++        8.03      -2.65
# 3              4             4                  Java        7.90      -0.94
# 4              5             5                    C#        4.85       0.17
# 5              6             6            JavaScript        3.04      -0.17
# 6              7             8          Visual Basic        2.80       0.59
# 7              8            12                   SQL        1.77       0.23
# 8              9            14                     R        1.69       0.30
# 9             10             9  Delphi/Object Pascal        1.54      -0.60
# 10            11            16               Scratch        1.46       0.27
# 11            12            18                  Rust        1.26       0.30
# 12            13             7                    Go        1.20      -1.08
# 13            14            15                   PHP        1.17      -0.08
# 14            15            25                 Swift        1.00       0.27
# 15            16            11                   Ada        0.97      -0.74
# 16            17            10               Fortran        0.95      -0.91
# 17            18            13                  Perl        0.92      -0.55
# 18            19            19     Assembly language        0.87      -0.04
# 19            20            17                MATLAB        0.85      -0.28
#
#     paradigma_principal
# 0        multiparadigma
# 1            imperativo
# 2        multiparadigma
# 3   orientado a objetos
# 4   orientado a objetos
# 5        multiparadigma
# 6   orientado a eventos
# 7           declarativo
# 8             funcional
# 9   orientado a objetos
# 10               visual
# 11       multiparadigma
# 12           imperativo
# 13       multiparadigma
# 14       multiparadigma
# 15           imperativo
# 16           imperativo
# 17       multiparadigma
# 18           bajo nivel
# 19       multiparadigma

# %% [markdown]
# ## 3. Informacion general del dataset

# %%
df.shape
# Out:
# (20, 6)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ranking_2026         20 non-null     int64
#  1   ranking_2025         20 non-null     int64
#  2   lenguaje             20 non-null     str
#  3   porcentaje           20 non-null     float64
#  4   variacion            20 non-null     float64
#  5   paradigma_principal  20 non-null     str
# dtypes: float64(2), int64(2), str(2)
# memory usage: 1.1 KB

# %%
df.describe(include="all")
# Out:
#         ranking_2026  ranking_2025 lenguaje  porcentaje  variacion  \
# count       20.00000     20.000000       20   20.000000  20.000000
# unique           NaN           NaN       20         NaN        NaN
# top              NaN           NaN   Python         NaN        NaN
# freq             NaN           NaN        1         NaN        NaN
# mean        10.50000     10.750000      NaN    3.600000  -0.576000
# std          5.91608      6.422616      NaN    4.610214   1.698053
# min          1.00000      1.000000      NaN    0.850000  -6.910000
# 25%          5.75000      5.750000      NaN    0.992500  -0.782500
# 50%         10.50000     10.500000      NaN    1.500000  -0.125000
# 75%         15.25000     15.250000      NaN    3.492500   0.270000
# max         20.00000     25.000000      NaN   18.960000   1.300000
#
#        paradigma_principal
# count                   20
# unique                   8
# top         multiparadigma
# freq                     8
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN

# %% [markdown]
# ## 4. Valores nulos y duplicados

# %%
df.isnull().sum()
# Out:
# ranking_2026           0
# ranking_2025           0
# lenguaje               0
# porcentaje             0
# variacion              0
# paradigma_principal    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 5. Limpieza de datos
#
# Aunque el dataset ya fue creado de forma ordenada, se aplica una limpieza basica para respetar el proceso de analisis.

# %%
df_limpio = df.drop_duplicates().copy()
df_limpio = df_limpio.fillna("N/A")
df_limpio["lenguaje"] = df_limpio["lenguaje"].str.strip()
df_limpio["paradigma_principal"] = df_limpio["paradigma_principal"].str.lower().str.strip()

df_limpio.head()
# Out:
#    ranking_2026  ranking_2025 lenguaje  porcentaje  variacion  \
# 0             1             1   Python       18.96      -6.91
# 1             2             3        C       10.77       1.30
# 2             3             2      C++        8.03      -2.65
# 3             4             4     Java        7.90      -0.94
# 4             5             5       C#        4.85       0.17
#
#    paradigma_principal
# 0       multiparadigma
# 1           imperativo
# 2       multiparadigma
# 3  orientado a objetos
# 4  orientado a objetos

# %% [markdown]
# ## 6. Top 10 de lenguajes mas usados
#
# Los diez primeros puestos del ranking para ver cuales son los lenguajes mas populares.

# %%
top_10 = df_limpio.sort_values("ranking_2026").head(10)
top_10
# Out:
#    ranking_2026  ranking_2025              lenguaje  porcentaje  variacion  \
# 0             1             1                Python       18.96      -6.91
# 1             2             3                     C       10.77       1.30
# 2             3             2                   C++        8.03      -2.65
# 3             4             4                  Java        7.90      -0.94
# 4             5             5                    C#        4.85       0.17
# 5             6             6            JavaScript        3.04      -0.17
# 6             7             8          Visual Basic        2.80       0.59
# 7             8            12                   SQL        1.77       0.23
# 8             9            14                     R        1.69       0.30
# 9            10             9  Delphi/Object Pascal        1.54      -0.60
#
#    paradigma_principal
# 0       multiparadigma
# 1           imperativo
# 2       multiparadigma
# 3  orientado a objetos
# 4  orientado a objetos
# 5       multiparadigma
# 6  orientado a eventos
# 7          declarativo
# 8            funcional
# 9  orientado a objetos

# %%
plt.figure(figsize=(10, 5))
plt.bar(top_10["lenguaje"], top_10["porcentaje"], color="#2f6f8f")
plt.title("Top 10 de lenguajes mas usados")
plt.xlabel("Lenguaje")
plt.ylabel("Popularidad (%)")
plt.xticks(rotation=45, ha="right")
plt.grid(axis="y", alpha=0.3)
plt.show()

# %% [markdown]
# ## 7. Comparacion entre ranking 2026 y ranking 2025
#
# Ranking de lenguajes que subieron, bajaron o se mantuvieron.

# %%
df_limpio["cambio_posicion"] = df_limpio["ranking_2025"] - df_limpio["ranking_2026"]

df_limpio[["lenguaje", "ranking_2026", "ranking_2025", "cambio_posicion"]].sort_values(
    "cambio_posicion", ascending=False
)
# Out:
#                 lenguaje  ranking_2026  ranking_2025  cambio_posicion
# 14                 Swift            15            25               10
# 11                  Rust            12            18                6
# 8                      R             9            14                5
# 10               Scratch            11            16                5
# 7                    SQL             8            12                4
# 6           Visual Basic             7             8                1
# 13                   PHP            14            15                1
# 1                      C             2             3                1
# 18     Assembly language            19            19                0
# 3                   Java             4             4                0
# 0                 Python             1             1                0
# 5             JavaScript             6             6                0
# 4                     C#             5             5                0
# 2                    C++             3             2               -1
# 9   Delphi/Object Pascal            10             9               -1
# 19                MATLAB            20            17               -3
# 17                  Perl            18            13               -5
# 15                   Ada            16            11               -5
# 12                    Go            13             7               -6
# 16               Fortran            17            10               -7

# %%
cambios = df_limpio.sort_values("cambio_posicion", ascending=True)
colores = ["#b56576" if valor < 0 else "#4c956c" if valor > 0 else "#6c757d" for valor in cambios["cambio_posicion"]]

plt.figure(figsize=(10, 6))
plt.barh(cambios["lenguaje"], cambios["cambio_posicion"], color=colores)
plt.title("Cambio de posicion respecto al ano anterior")
plt.xlabel("Posiciones ganadas o perdidas")
plt.ylabel("Lenguaje")
plt.axvline(0, color="black", linewidth=0.8)
plt.grid(axis="x", alpha=0.3)
plt.show()

# %% [markdown]
# ## 8. Lenguajes que mas crecieron y mas bajaron

# %%
mas_crecieron = df_limpio.sort_values("variacion", ascending=False).head(5)
mas_bajaron = df_limpio.sort_values("variacion").head(5)

display(mas_crecieron[["lenguaje", "porcentaje", "variacion"]])
display(mas_bajaron[["lenguaje", "porcentaje", "variacion"]])
# Out:
#         lenguaje  porcentaje  variacion
# 1              C       10.77       1.30
# 6   Visual Basic        2.80       0.59
# 8              R        1.69       0.30
# 11          Rust        1.26       0.30
# 14         Swift        1.00       0.27
#    lenguaje  porcentaje  variacion
# 0    Python       18.96      -6.91
# 2       C++        8.03      -2.65
# 12       Go        1.20      -1.08
# 3      Java        7.90      -0.94
# 16  Fortran        0.95      -0.91

# %%
plt.figure(figsize=(10, 5))
plt.bar(df_limpio["lenguaje"], df_limpio["variacion"], color="#6a994e")
plt.title("Variacion de popularidad en puntos porcentuales")
plt.xlabel("Lenguaje")
plt.ylabel("Variacion")
plt.xticks(rotation=60, ha="right")
plt.axhline(0, color="black", linewidth=0.8)
plt.grid(axis="y", alpha=0.3)
plt.show()

# %% [markdown]
# ## 9. Paradigmas principales
#
# Agrupo los lenguajes por el paradigma principal asignado en el dataset.

# %%
conteo_paradigmas = df_limpio["paradigma_principal"].value_counts()
conteo_paradigmas
# Out:
# paradigma_principal
# multiparadigma         8
# imperativo             4
# orientado a objetos    3
# orientado a eventos    1
# declarativo            1
# funcional              1
# visual                 1
# bajo nivel             1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))
conteo_paradigmas.sort_values().plot(kind="barh", color="#b56576")
plt.title("Cantidad de lenguajes por paradigma principal")
plt.xlabel("Cantidad")
plt.ylabel("Paradigma")
plt.grid(axis="x", alpha=0.3)
plt.show()

# %% [markdown]
# ## 10. Conclusion
#
# El ranking muestra que Python ocupa el primer lugar entre los lenguajes mas populares, seguido por C, C++, Java y C#. Tambien se observa que algunos lenguajes subieron posiciones respecto del ano anterior, como Swift, Rust, Scratch, R y SQL.
